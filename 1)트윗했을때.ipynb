# %%
# Out:
# 가격 데이터: (790517, 6)
#                         open
# datetime
# 2016-11-07 00:02:00  2105.50
# 2016-11-07 00:03:00  2105.75
# 2016-11-07 00:04:00  2106.25
# 2016-11-07 00:05:00  2105.75
# 2016-11-07 00:12:00  2106.00
#
# 트윗(기간필터) 개수: 8846
#                      n_tweets
# datetime
# 2016-11-08 06:42:00         1
# 2016-11-08 11:43:00         1
# 2016-11-08 16:39:00         1
# 2016-11-08 18:03:00         1
# 2016-11-08 18:23:00         1
#
# 수익률 예시:
#                        ret_1m
# datetime
# 2016-11-07 00:02:00  0.000119
# 2016-11-07 00:03:00  0.000237
# 2016-11-07 00:04:00 -0.000237
# 2016-11-07 00:05:00  0.000119
# 2016-11-07 00:12:00  0.000119
#
# 병합 확인:
#                         open  n_tweets  tweet_dummy
# datetime
# 2016-11-07 00:02:00  2105.50       NaN            0
# 2016-11-07 00:03:00  2105.75       NaN            0
# 2016-11-07 00:04:00  2106.25       NaN            0
# 2016-11-07 00:05:00  2105.75       NaN            0
# ...

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 8
#       4 # -------------------------
#       5 # 설정
#       6 # -------------------------
#       7 MAX_H = 120  # 최대 120분
# ----> 8 event_times = tariff_flag.loc[tariff_flag["Tariff_t"] == 1, "px_time_et"]
#      10 # 가격 데이터 (ET 기준, 정렬)
#      11 px_ev = px_rth.sort_values("px_time_et").reset_index(drop=True)
#
# NameError: name 'tariff_flag' is not defined
